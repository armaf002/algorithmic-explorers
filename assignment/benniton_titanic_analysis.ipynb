# %%
import pandas as pd
import matplotlib.pyplot as plot
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Otpat\Downloads\titanic_data.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'] = df['Age'].apply(lambda x: str(x))
df['Age'] = df['Age'].str.replace('nan', '')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Cabin'] = df['Cabin'].apply(lambda x: str(x))
df['Cabin'] = df['Cabin'].str.replace('nan', '')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Embarked'] = df['Embarked'].apply(lambda x: str(x))
df['Embarked'] = df['Embarked'].str.replace('nan', '')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df['Name'] = df['Name'].str.replace(r'\(.*?\)', '', regex=True)
df
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 1              2         1       1               Cumings, Mrs. John Bradley
# 2              3         1       3                    Heikkinen, Miss. Laina
# 3              4         1       1             Futrelle, Mrs. Jacques Heath
# 4              5         0       3                  Allen, Mr. William Henry
# ..           ...       ...     ...                                       ...
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df['Name'] = df['Name'].str.replace(r'"[^"]*"', '', regex=True)
df
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 0              1         0       3           Braund, Mr. Owen Harris    male
# 1              2         1       1       Cumings, Mrs. John Bradley   female
# 2              3         1       3            Heikkinen, Miss. Laina  female
# 3              4         1       1     Futrelle, Mrs. Jacques Heath   female
# 4              5         0       3          Allen, Mr. William Henry    male
# ..           ...       ...     ...                               ...     ...
# 886          887         0       2             Montvila, Rev. Juozas    male
# 887          888         1       1      Graham, Miss. Margaret Edith  female
# 888          889         0       3  Johnston, Miss. Catherine Helen   female
# 889          890         1       1             Behr, Mr. Karl Howell    male
# 890          891         0       3               Dooley, Mr. Patrick    male
#
# ...

# %%
# Function to move text after the comma to the front
def name_reposition(text):
    if ',' in text:  # Check if the string contains a comma
        parts = text.split(',', 1)  # Split the string into two parts at the first comma
        return parts[1].strip() + ' ' + parts[0].strip()  # Move text after comma to the front
    return text  # Return unchanged if no comma is present

# Apply the function to the 'Name' column
df['Name'] = df['Name'].apply(name_reposition)
df
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 0              1         0       3          Mr. Owen Harris Braund    male
# 1              2         1       1       Mrs. John Bradley Cumings  female
# 2              3         1       3           Miss. Laina Heikkinen  female
# 3              4         1       1     Mrs. Jacques Heath Futrelle  female
# 4              5         0       3         Mr. William Henry Allen    male
# ..           ...       ...     ...                             ...     ...
# 886          887         0       2            Rev. Juozas Montvila    male
# 887          888         1       1     Miss. Margaret Edith Graham  female
# 888          889         0       3  Miss. Catherine Helen Johnston  female
# 889          890         1       1            Mr. Karl Howell Behr    male
# 890          891         0       3              Mr. Patrick Dooley    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    object
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 83.7+ KB

# %%
df['Ticket'].value_counts()
# Out:
# Ticket
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: count, Length: 681, dtype: int64

# %%
df[df['Ticket']=='347082']
# Out:
#      PassengerId  Survived  Pclass                                    Name  \
# 13            14         0       3              Mr. Anders Johan Andersson
# 119          120         0       3        Miss. Ellis Anna Maria Andersson
# 541          542         0       3     Miss. Ingeborg Constanzia Andersson
# 542          543         0       3        Miss. Sigrid Elisabeth Andersson
# 610          611         0       3             Mrs. Anders Johan Andersson
# 813          814         0       3       Miss. Ebba Iris Alfrida Andersson
# 850          851         0       3  Master. Sigvard Harald Elias Andersson
#
#         Sex   Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 13     male  39.0      1      5  347082  31.275              S
# 119  female   2.0      4      2  347082  31.275              S
# 541  female   9.0      4      2  347082  31.275              S
# 542  female  11.0      4      2  347082  31.275              S
# ...

# %%
df['Ticket'] = df['Ticket'].drop_duplicates()
df[df['Ticket']=='347082']
# Out:
#     PassengerId  Survived  Pclass                        Name   Sex   Age  \
# 13           14         0       3  Mr. Anders Johan Andersson  male  39.0
#
#     SibSp  Parch  Ticket    Fare Cabin Embarked
# 13      1      5  347082  31.275              S

# %%
df['Ticket'].value_counts()
# Out:
# Ticket
#              210
# A/5 21171      1
# 2620           1
# 13568          1
# WE/P 5735      1
#             ...
# PC 17585       1
# 110152         1
# PC 17755       1
# 230433         1
# 370376         1
# Name: count, Length: 682, dtype: int64

# %%
df['Ticket'] = df['Ticket'].fillna('')

# %%
df
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 0              1         0       3          Mr. Owen Harris Braund    male
# 1              2         1       1       Mrs. John Bradley Cumings  female
# 2              3         1       3           Miss. Laina Heikkinen  female
# 3              4         1       1     Mrs. Jacques Heath Futrelle  female
# 4              5         0       3         Mr. William Henry Allen    male
# ..           ...       ...     ...                             ...     ...
# 886          887         0       2            Rev. Juozas Montvila    male
# 887          888         1       1     Miss. Margaret Edith Graham  female
# 888          889         0       3  Miss. Catherine Helen Johnston  female
# 889          890         1       1            Mr. Karl Howell Behr    male
# 890          891         0       3              Mr. Patrick Dooley    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df['Sex'] = df['Sex'].replace({'female':'Female', 'male':'Male'})

# %%
df.head(50)
# Out:
#              Survived  Pclass                                     Name  \
# PassengerId
# 1                   0       3                   Mr. Owen Harris Braund
# 2                   1       1                Mrs. John Bradley Cumings
# 3                   1       3                    Miss. Laina Heikkinen
# 4                   1       1              Mrs. Jacques Heath Futrelle
# 5                   0       3                  Mr. William Henry Allen
# 6                   0       3                          Mr. James Moran
# 7                   0       1                   Mr. Timothy J McCarthy
# 8                   0       3            Master. Gosta Leonard Palsson
# 9                   1       3                     Mrs. Oscar W Johnson
# 10                  1       2                     Mrs. Nicholas Nasser
# 11                  1       3           Miss. Marguerite Rut Sandstrom
# 12                  1       1                  Miss. Elizabeth Bonnell
# ...

# %%
df.set_index('PassengerId', inplace=True)

# %%
df['Sex'] = df['Sex'].replace('feMale', 'Female')
df
# Out:
#              Survived  Pclass                            Name     Sex   Age  \
# PassengerId
# 1                   0       3          Mr. Owen Harris Braund    Male  22.0
# 2                   1       1       Mrs. John Bradley Cumings  Female  38.0
# 3                   1       3           Miss. Laina Heikkinen  Female  26.0
# 4                   1       1     Mrs. Jacques Heath Futrelle  Female  35.0
# 5                   0       3         Mr. William Henry Allen    Male  35.0
# ...               ...     ...                             ...     ...   ...
# 887                 0       2            Rev. Juozas Montvila    Male  27.0
# 888                 1       1     Miss. Margaret Edith Graham  Female  19.0
# 889                 0       3  Miss. Catherine Helen Johnston  Female
# 890                 1       1            Mr. Karl Howell Behr    Male  26.0
# 891                 0       3              Mr. Patrick Dooley    Male  32.0
#
# ...

# %%
for x in df.index:
    if df.loc[x, 'Age'] == '':
        df.drop(x, inplace=True)
df
# Out:
#              Survived  Pclass                         Name     Sex   Age  \
# PassengerId
# 1                   0       3       Mr. Owen Harris Braund    Male  22.0
# 2                   1       1    Mrs. John Bradley Cumings  Female  38.0
# 3                   1       3        Miss. Laina Heikkinen  Female  26.0
# 4                   1       1  Mrs. Jacques Heath Futrelle  Female  35.0
# 5                   0       3      Mr. William Henry Allen    Male  35.0
# ...               ...     ...                          ...     ...   ...
# 886                 0       3            Mrs. William Rice  Female  39.0
# 887                 0       2         Rev. Juozas Montvila    Male  27.0
# 888                 1       1  Miss. Margaret Edith Graham  Female  19.0
# 890                 1       1         Mr. Karl Howell Behr    Male  26.0
# 891                 0       3           Mr. Patrick Dooley    Male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop(['Ticket', 'SibSp', 'Fare', 'Parch'], axis=1, errors='ignore')
df
# Out:
#              Survived  Pclass                         Name     Sex   Age  \
# PassengerId
# 1                   0       3       Mr. Owen Harris Braund    Male  22.0
# 2                   1       1    Mrs. John Bradley Cumings  Female  38.0
# 3                   1       3        Miss. Laina Heikkinen  Female  26.0
# 4                   1       1  Mrs. Jacques Heath Futrelle  Female  35.0
# 5                   0       3      Mr. William Henry Allen    Male  35.0
# ...               ...     ...                          ...     ...   ...
# 886                 0       3            Mrs. William Rice  Female  39.0
# 887                 0       2         Rev. Juozas Montvila    Male  27.0
# 888                 1       1  Miss. Margaret Edith Graham  Female  19.0
# 890                 1       1         Mr. Karl Howell Behr    Male  26.0
# 891                 0       3           Mr. Patrick Dooley    Male  32.0
#
#             Cabin Embarked
# PassengerId
# 1                        S
# ...

# %%
df = df[['Name', 'Sex', 'Age', 'Cabin', 'Pclass', 'Survived', 'Embarked']]
df
# Out:
#                                     Name     Sex   Age Cabin  Pclass  \
# PassengerId
# 1                 Mr. Owen Harris Braund    Male  22.0             3
# 2              Mrs. John Bradley Cumings  Female  38.0   C85       1
# 3                  Miss. Laina Heikkinen  Female  26.0             3
# 4            Mrs. Jacques Heath Futrelle  Female  35.0  C123       1
# 5                Mr. William Henry Allen    Male  35.0             3
# ...                                  ...     ...   ...   ...     ...
# 886                    Mrs. William Rice  Female  39.0             3
# 887                 Rev. Juozas Montvila    Male  27.0             2
# 888          Miss. Margaret Edith Graham  Female  19.0   B42       1
# 890                 Mr. Karl Howell Behr    Male  26.0  C148       1
# 891                   Mr. Patrick Dooley    Male  32.0             3
#
#              Survived Embarked
# PassengerId
# 1                   0        S
# 2                   1        C
# ...

# %%
pd.set_option('display.max.rows', 891)

# %%
df
# Out:
#                                                        Name     Sex   Age  \
# PassengerId
# 1                                    Mr. Owen Harris Braund    Male  22.0
# 2                                 Mrs. John Bradley Cumings  Female  38.0
# 3                                     Miss. Laina Heikkinen  Female  26.0
# 4                               Mrs. Jacques Heath Futrelle  Female  35.0
# 5                                   Mr. William Henry Allen    Male  35.0
# 7                                    Mr. Timothy J McCarthy    Male  54.0
# 8                             Master. Gosta Leonard Palsson    Male   2.0
# 9                                      Mrs. Oscar W Johnson  Female  27.0
# 10                                     Mrs. Nicholas Nasser  Female  14.0
# 11                           Miss. Marguerite Rut Sandstrom  Female   4.0
# 12                                  Miss. Elizabeth Bonnell  Female  58.0
# ...

# %%
df[df['Name'].str.contains(r'\b[A-Za-z]\b', regex=True)]
# Out:
#                                                    Name     Sex   Age  \
# PassengerId
# 7                                Mr. Timothy J McCarthy    Male  54.0
# 9                                  Mrs. Oscar W Johnson  Female  27.0
# 21                                  Mr. Joseph J Fynney    Male  35.0
# 31                              Don. Manuel E Uruchurtu    Male  40.0
# 34                                 Mr. Edward H Wheadon    Male  66.0
# 84                               Mr. Francisco M Carrau    Male  28.0
# 97                             Mr. George B Goldschmidt    Male  71.0
# 99                                   Mrs. John T Doling  Female  34.0
# 133                             Mrs. Alexander A Robins  Female  47.0
# 184                            Master. Richard F Becker    Male   1.0
# 194                           Master. Michel M Navratil    Male   3.0
# 222                                 Mr. James H Bracken    Male  27.0
# ...

# %%
df
# Out:
#                                                        Name     Sex   Age  \
# PassengerId
# 1                                    Mr. Owen Harris Braund    Male  22.0
# 2                                 Mrs. John Bradley Cumings  Female  38.0
# 3                                     Miss. Laina Heikkinen  Female  26.0
# 4                               Mrs. Jacques Heath Futrelle  Female  35.0
# 5                                   Mr. William Henry Allen    Male  35.0
# 7                                    Mr. Timothy J McCarthy    Male  54.0
# 8                             Master. Gosta Leonard Palsson    Male   2.0
# 9                                      Mrs. Oscar W Johnson  Female  27.0
# 10                                     Mrs. Nicholas Nasser  Female  14.0
# 11                           Miss. Marguerite Rut Sandstrom  Female   4.0
# 12                                  Miss. Elizabeth Bonnell  Female  58.0
# ...
